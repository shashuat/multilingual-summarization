# %%
# train
metrics = {
    "german": {
        "german": {
    "base_model": {
      "rouge-1": 0.24858897331880242,
      "rouge-2": 0.06879419458279615,
      "rouge-l": 0.22953858858862006
    },
    "finetuned_model": {
      "rouge-1": 0.5995098079291682,
      "rouge-2": 0.45479016368367914,
      "rouge-l": 0.5860987479902617
    }
        },
        "english": {
    "base_model": {
      "rouge-1": 0.2927662864881104,
      "rouge-2": 0.11872378478806551,
      "rouge-l": 0.2845063913561303
    },
    "finetuned_model": {
      "rouge-1": 0.37405080972356025,
      "rouge-2": 0.17101454771358234,
      "rouge-l": 0.34557993954593436
    }
        },
        "french": {
    "base_model": {
      "rouge-1": 0.268752288322266,
      "rouge-2": 0.09546773405763681,
      "rouge-l": 0.25157966758720124
    },
    "finetuned_model": {
      "rouge-1": 0.35909458082886153,
      "rouge-2": 0.1512160159950959,
      "rouge-l": 0.34108195674840596
    }
        }
    },
    "english": {
        "german": 
        {
    "base_model": {
      "rouge-1": 0.2408650069278229,
      "rouge-2": 0.06394329533006389,
      "rouge-l": 0.22453403529152988
    },
    "finetuned_model": {
      "rouge-1": 0.3099775501878988,
      "rouge-2": 0.10505709104432767,
      "rouge-l": 0.2918996132434496
    }
    },
        "english": 
        {
    "base_model": {
      "rouge-1": 0.31237933480122787,
      "rouge-2": 0.11871564468522887,
      "rouge-l": 0.2845795333100445
    },
    "finetuned_model": {
      "rouge-1": 0.3758223926599203,
      "rouge-2": 0.16017708169594588,
      "rouge-l": 0.34664132836231853
    }
    },
        "french": 
        {
    "base_model": {
      "rouge-1": 0.2741819687089197,
      "rouge-2": 0.09516643483049689,
      "rouge-l": 0.2531932497003447
    },
    "finetuned_model": {
      "rouge-1": 0.351551329105671,
      "rouge-2": 0.14988622793320006,
      "rouge-l": 0.329101585029652
    }
         }
    },
    "french": {
        "german": {
    "base_model": {
      "rouge-1": 0.24640414574638053,
      "rouge-2": 0.06524899121812182,
      "rouge-l": 0.2291586051434793
    },
    "finetuned_model": {
      "rouge-1": 0.32049894169344195,
      "rouge-2": 0.11735332800279051,
      "rouge-l": 0.302151822560694
    }
            },
        "english": {
    "base_model": {
      "rouge-1": 0.30991129274913315,
      "rouge-2": 0.11804003328165069,
      "rouge-l": 0.2832888306374475
    },
    "finetuned_model": {
      "rouge-1": 0.3989345067808585,
      "rouge-2": 0.18480111570663402,
      "rouge-l": 0.37052838272032373
    }
            },
        "french": {
    "base_model": {
      "rouge-1": 0.27688716503512695,
      "rouge-2": 0.09293457394377372,
      "rouge-l": 0.2552370989877742
    },
    "finetuned_model": {
      "rouge-1": 0.7403868937913833,
      "rouge-2": 0.6562684895223796,
      "rouge-l": 0.731159448811898
    }
            }
    }
}
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Function to compute percentage improvement scores
def compute_percentage_improvement(metrics, metric_name):
    return [
        [
            (
                (metrics[finetuned_language][test_language]["finetuned_model"].get(metric_name, 0) - 
                 metrics[finetuned_language][test_language]["base_model"].get(metric_name, 0)) / 
                metrics[finetuned_language][test_language]["base_model"].get(metric_name, 1)  # Avoid division by zero
            ) * 100
            for test_language in ["german", "english", "french"]
        ]
        for finetuned_language in ["german", "english", "french"]
    ]

# Function to plot heatmap
def plot_heatmap(data, title, ax):
    sns.heatmap(data, annot=True, cmap="crest", fmt=".1f", cbar=True, 
                xticklabels=["German", "English", "French"], 
                yticklabels=["German", "Japanese", "French"], ax=ax)
    ax.set_title(title)
    ax.set_xlabel("Summary Language (Same article as train set)")
    ax.set_ylabel("Finetuned Model Language")

# Compute percentage improvement matrices for different ROUGE metrics
percentage_improvement_rouge1 = compute_percentage_improvement(metrics, "rouge-1")
percentage_improvement_rouge2 = compute_percentage_improvement(metrics, "rouge-2")
percentage_improvement_rougel = compute_percentage_improvement(metrics, "rouge-l")

# Create figure with subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plot heatmaps for different ROUGE metrics
plot_heatmap(np.array(percentage_improvement_rouge1), "ROUGE-1 % Improvement", axes[0])
plot_heatmap(np.array(percentage_improvement_rouge2), "ROUGE-2 % Improvement", axes[1])
plot_heatmap(np.array(percentage_improvement_rougel), "ROUGE-L % Improvement", axes[2])

# Display the plots
plt.tight_layout()
plt.show()

# %%
# Placeholder dictionaries for base and finetuned models
# Format: {finetuned_model_language: {test_language: {"base_model": {...}, "finetuned_model": {...}}}}
metrics = {
    "german": {
        "german": {
    "base_model": {
      "rouge-1": 0.24998317785690036,
      "rouge-2": 0.0669507368816298,
      "rouge-l": 0.23203590859172532
    },
    "finetuned_model": {
      "rouge-1": 0.4017324360553695,
      "rouge-2": 0.17625054853215685,
      "rouge-l": 0.37836669955690977
    }
        },
        "english": {
    "base_model": {
      "rouge-1": 0.3060395981644797,
      "rouge-2": 0.1158101443656595,
      "rouge-l": 0.2797602217054977
    },
    "finetuned_model": {
      "rouge-1": 0.3800726106300021,
      "rouge-2": 0.16590252189032886,
      "rouge-l": 0.3520546734200655
    }
        },
        "french": {
    "base_model": {
      "rouge-1": 0.2722129411254417,
      "rouge-2": 0.09352556269100491,
      "rouge-l": 0.25073952527879656
    },
    "finetuned_model": {
      "rouge-1": 0.35506220291788226,
      "rouge-2": 0.1537933431682964,
      "rouge-l": 0.3313138972798104
    }
        }
    },
    "english": {
        "german": 
        {
    "base_model": {
      "rouge-1": 0.24975111510573758,
      "rouge-2": 0.06772196614991435,
      "rouge-l": 0.23382584459595365
    },
    "finetuned_model": {
      "rouge-1": 0.3109142297377817,
      "rouge-2": 0.10493033150392228,
      "rouge-l": 0.2921598374226826
    }
    },
        "english": 
        {
    "base_model": {
      "rouge-1": 0.30997162302050263,
      "rouge-2": 0.11725778122922635,
      "rouge-l": 0.28223078608327384
    },
    "finetuned_model": {
      "rouge-1": 0.3811028225409452,
      "rouge-2": 0.16399354925024603,
      "rouge-l": 0.3550844857908262
    }
    },
        "french": 
        {
    "base_model": {
      "rouge-1": 0.2741819687089197,
      "rouge-2": 0.09516643483049689,
      "rouge-l": 0.2531932497003447
    },
    "finetuned_model": {
      "rouge-1": 0.351551329105671,
      "rouge-2": 0.14988622793320006,
      "rouge-l": 0.329101585029652
    }
         }
    },
    "french": {
        "german": {
    "base_model": {
      "rouge-1": 0.25129900609006245,
      "rouge-2": 0.06673821313995285,
      "rouge-l": 0.23372225985247475
    },
    "finetuned_model": {
      "rouge-1": 0.3302274684110302,
      "rouge-2": 0.12369190533148242,
      "rouge-l": 0.3110908059950198
    }
            },
        "english": {
    "base_model": {
      "rouge-1": 0.31462023788434745,
      "rouge-2": 0.11776231043308961,
      "rouge-l": 0.2871543843445197
    },
    "finetuned_model": {
      "rouge-1": 0.39866542672522903,
      "rouge-2": 0.18723599304062372,
      "rouge-l": 0.36980152282899553
    }
            },
        "french": {
    "base_model": {
      "rouge-1": 0.2653934168655436,
      "rouge-2": 0.0895530124372072,
      "rouge-l": 0.24444726333685357
    },
    "finetuned_model": {
      "rouge-1": 0.4799867585846595,
      "rouge-2": 0.27041747840030694,
      "rouge-l": 0.4517621583466832
    }
            }
    }
}
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Function to compute percentage improvement scores
def compute_percentage_improvement(metrics, metric_name):
    return [
        [
            (
                (metrics[finetuned_language][test_language]["finetuned_model"].get(metric_name, 0) - 
                 metrics[finetuned_language][test_language]["base_model"].get(metric_name, 0)) / 
                metrics[finetuned_language][test_language]["base_model"].get(metric_name, 1)  # Avoid division by zero
            ) * 100
            for test_language in ["german", "english", "french"]
        ]
        for finetuned_language in ["german", "english", "french"]
    ]

# Function to plot heatmap
def plot_heatmap(data, title, ax):
    sns.heatmap(data, annot=True, cmap="crest", fmt=".1f", cbar=True, 
                xticklabels=["German", "English", "French"], 
                yticklabels=["German", "Japanese", "French"], ax=ax)
    ax.set_title(title)
    ax.set_xlabel("Summary Language (Test Set)")
    ax.set_ylabel("Finetuned Model Language")

# Compute percentage improvement matrices for different ROUGE metrics
percentage_improvement_rouge1 = compute_percentage_improvement(metrics, "rouge-1")
percentage_improvement_rouge2 = compute_percentage_improvement(metrics, "rouge-2")
percentage_improvement_rougel = compute_percentage_improvement(metrics, "rouge-l")

# Create figure with subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plot heatmaps for different ROUGE metrics
plot_heatmap(np.array(percentage_improvement_rouge1), "ROUGE-1 % Improvement", axes[0])
plot_heatmap(np.array(percentage_improvement_rouge2), "ROUGE-2 % Improvement", axes[1])
plot_heatmap(np.array(percentage_improvement_rougel), "ROUGE-L % Improvement", axes[2])

# Display the plots
plt.tight_layout()
plt.show()

# test
